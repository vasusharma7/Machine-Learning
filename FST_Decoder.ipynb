# %% [markdown]
# <a href="https://colab.research.google.com/github/vasusharma7/Machine-Learning/blob/master/FST_Decoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch==2.5.1 transformers==4.49.0 accelerate==1.3.0
# Out:
# ...
#   Using cached torch-2.5.1-cp312-cp312-manylinux1_x86_64.whl.metadata (28 kB)
# ...
#   Using cached transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
# ...
#   Using cached accelerate-1.3.0-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...

# %%
# !pip install torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.7/530.7 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.1/366.1 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 MB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 MB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 93.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 MB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 108.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 74.5 MB/s eta 0:00:00
# ...

# %%
# !pip install --force-reinstall torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.4 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

torch.random.manual_seed(0)

model_path = "microsoft/Phi-4-mini-instruct"

model = AutoModelForCausalLM.from_pretrained(
    model_path,
    device_map="auto",
    torch_dtype="auto",
    trust_remote_code=True,
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.

# %%
tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)

# %%
messages = [
    {"role": "system", "content": "You are a helpful AI assistant."},
    {"role": "user", "content": "Can you provide ways to eat combinations of bananas and dragonfruits?"},
    {"role": "assistant", "content": "Sure! Here are some ways to eat bananas and dragonfruits together: 1. Banana and dragonfruit smoothie: Blend bananas and dragonfruits together with some milk and honey. 2. Banana and dragonfruit salad: Mix sliced bananas and dragonfruits together with some lemon juice and honey."},
    {"role": "user", "content": "What about solving an 2x + 3 = 7 equation?"},
]

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    logits_processor = LogitsProcessorList([])
)

generation_args = {
    "max_new_tokens": 500,
    "return_full_text": False,
    "temperature": 0.0,
    "do_sample": False,
}

output = pipe(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
# Device set to use cuda:0
# /usr/local/lib/python3.12/dist-packages/transformers/generation/configuration_utils.py:629: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# To solve the equation 2x + 3 = 7, follow these steps:
#
# 1. Subtract 3 from both sides of the equation to isolate the term with the variable (x) on one side:
#    2x + 3 - 3 = 7 - 3
#    2x = 4
#
# 2. Divide both sides of the equation by 2 to solve for x:
#    2x / 2 = 4 / 2
#    x = 2
#
# So, the solution to the equation 2x + 3 = 7 is x = 2.

# %%
class JSONFST:
    def __init__(self):
        # We track state as a stack of nested symbols to ensure structural integrity
        self.state = "START"
        self.stack = []

    def step(self, char):
        """Standard JSON structural state transitions."""
        # Whitespace is ignored in structural transitions
        if char.isspace(): return

        if self.state == "START":
            if char == '{': self.state = "EXPECT_KEY"; self.stack.append('OBJ')
            elif char == '[': self.state = "EXPECT_VAL"; self.stack.append('ARR')

        elif self.state == "EXPECT_KEY":
            if char == '"': self.state = "KEY"
            elif char == '}': self.stack.pop(); self.state = "AFTER_VAL"

        elif self.state == "KEY":
            if char == '"': self.state = "EXPECT_COLON"

        elif self.state == "EXPECT_COLON":
            if char == ':': self.state = "EXPECT_VAL"

        elif self.state == "EXPECT_VAL":
            if char == '"': self.state = "VAL"
            elif char in '0123456789-': self.state = "NUMBER"|
            elif char == '{': self.state = "EXPECT_KEY"; self.stack.append('OBJ')
            elif char == '[': self.state = "EXPECT_VAL"; self.stack.append('ARR')

        elif self.state == "VAL":
            if char == '"': self.state = "AFTER_VAL"

        elif self.state == "AFTER_VAL":
            if char == ',': self.state = "EXPECT_KEY" if self.stack[-1] == 'OBJ' else "EXPECT_VAL"
            elif char == '}' and self.stack[-1] == 'OBJ': self.stack.pop(); self.state = "AFTER_VAL"
            elif char == ']' and self.stack[-1] == 'ARR': self.stack.pop(); self.state = "AFTER_VAL"

        elif self.state == "NUMBER":
            if char not in '0123456789.eE+-':
                # Re-process char in the 'AFTER_VAL' state
                self.state = "AFTER_VAL"
                self.step(char)

# %%
import torch
from transformers import LogitsProcessor

class UltraFastJSONLogitsProcessor(LogitsProcessor):
    def __init__(self, tokenizer, base_fst, device="cuda"):
        self.tokenizer = tokenizer
        self.fst = base_fst
        self.device = device
        self.base_vocab_size = len(tokenizer)
        self.prompt_length = None

        self.vocab_strings = []
        for token_id in range(self.base_vocab_size):
            t_str = self.tokenizer.decode([token_id], clean_up_tokenization_spaces=False)
            t_str = t_str.replace('Ġ', ' ').replace('Ċ', '\n').replace('ĉ', '\n')
            self.vocab_strings.append(t_str)

    def get_permissible_first_chars(self, state) -> set:
        digits = set("0123456789-")

        if state == "START":
            return set(['{', '['])
        elif state == "OBJ_EXPECT_KEY_OR_CLOSE":
            return set(['"', '}'])
        elif state in ["OBJ_KEY_STRING", "OBJ_VAL_STRING", "ARR_VAL_STRING", "OBJ_KEY_ESCAPE", "OBJ_VAL_STRING_ESCAPE", "ARR_VAL_STRING_ESCAPE"]:
            return set()
        elif state == "OBJ_EXPECT_COLON":
            return set([':'])
        elif state == "OBJ_EXPECT_VALUE" or state == "ARR_EXPECT_VAL_OR_CLOSE":
            return set(['{', '[', '"', 't', 'f', 'n', ']']).union(digits)
        elif state == "OBJ_EXPECT_COMMA_OR_CLOSE" or state == "ARR_EXPECT_COMMA_OR_CLOSE":
            return set([',', '}', ']'])
        elif state == "NUMBER":
            return digits.union(set(['.', 'e', 'E', '+', ',', '}', ']']))
        elif state == "LITERAL":
            return set("truefalsnull")
        return set()

    def __call__(self, input_ids: torch.LongTensor, scores: torch.FloatTensor) -> torch.FloatTensor:
        actual_vocab_size = scores.shape[-1]
        current_len = input_ids.shape[1]

        if self.prompt_length is None:
            self.prompt_length = current_len

        if current_len > self.prompt_length:
            last_token_id = input_ids[0, -1].item()
            if last_token_id < self.base_vocab_size:
                for char in self.vocab_strings[last_token_id]:
                    self.fst.step(char)

        if self.fst.state == "ERROR":
            scores.masked_fill_(torch.ones_like(scores, dtype=torch.bool), float('-inf'))
            return scores

        if self.fst.state in ["OBJ_KEY_STRING", "OBJ_VAL_STRING", "ARR_VAL_STRING", "OBJ_KEY_ESCAPE", "OBJ_VAL_STRING_ESCAPE", "ARR_VAL_STRING_ESCAPE"]:
            return scores

        allowed_chars = self.get_permissible_first_chars(self.fst.state)
        allowed_mask = torch.zeros(actual_vocab_size, dtype=torch.bool, device=self.device)

        allowed_indices = []
        for t_id, t_str in enumerate(self.vocab_strings):
            if not t_str:
                continue

            stripped = t_str.lstrip(' \n\r\t')

            if not stripped:
                # Pure whitespace tokens are safe
                allowed_indices.append(t_id)
                continue

            first_char = stripped[0]
            if first_char in allowed_chars:
                if first_char in '{}[]:,':
                    if any(c.isalpha() for c in stripped):
                        continue
                elif first_char in "0123456789-":
                    if any(c.isalpha() and c not in 'eE' for c in stripped):
                        continue

                allowed_indices.append(t_id)

        if allowed_indices:
            allowed_mask[allowed_indices] = True

        scores.masked_fill_(~allowed_mask, float('-inf'))
        return scores

# %%
# !pip install xgrammar
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 MB 31.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 105.4 MB/s eta 0:00:00
# ...

# %%
import torch
import xgrammar as xgr
from transformers import LogitsProcessor

class XGrammarLogitsProcessor(LogitsProcessor):
    def __init__(self, matcher, vocab_size):
        self.matcher = matcher
        self.vocab_size = vocab_size
        # Allocate a bitmask buffer once (as per xgrammar specs)
        self.bitmask = xgr.allocate_token_bitmask(1, vocab_size)

    def __call__(self, input_ids, scores):
        # 1. Fill the bitmask with allowed tokens based on current FSM state
        self.matcher.fill_next_token_bitmask(self.bitmask)

        # 2. Apply the bitmask to the logits (in-place)
        # Note: apply_token_bitmask_inplace is the official XGrammar method
        xgr.apply_token_bitmask_inplace(scores, self.bitmask)

        return scores

    def update(self, token_id):
        # Advance the grammar state machine
        self.matcher.accept_token(token_id)

# %%
import torch
import xgrammar as xgr
from transformers import AutoModelForCausalLM, AutoTokenizer

tokenizer_info = xgr.TokenizerInfo.from_huggingface(tokenizer)
compiler = xgr.GrammarCompiler(tokenizer_info)

json_schema = {
    "type": "object",
    "properties": {
        "name": {"type": "string"},
        "age": {"type": "integer"},
        "skills": {"type": "array", "items": {"type": "string"}}
    },
    "required": ["name", "age", "skills"]
}
compiled_grammar = compiler.compile_json_schema(json_schema)

matcher = xgr.GrammarMatcher(compiled_grammar)
token_bitmask = xgr.allocate_token_bitmask(1, tokenizer_info.vocab_size)

prompt = "Generate a profile for a developer named Alice who is 30 and knows Python."
input_ids = tokenizer.encode(prompt, return_tensors="pt")

# Initial mask
matcher.fill_next_token_bitmask(token_bitmask)

generated_ids = input_ids
for _ in range(100):  # max_new_tokens
    with torch.no_grad():
        logits = model(generated_ids).logits[:, -1, :]

    # Apply XGrammar bitmask to logits (infinitely suppresses invalid tokens)
    xgr.apply_token_bitmask_inplace(logits, token_bitmask)

    # Sample next token
    next_token = torch.argmax(logits, dim=-1, keepdim=True)

    # Update grammar state with the chosen token
    matcher.accept_token(next_token.item())

    if matcher.is_terminated(): # End Token Recieved
        print("Grammar constraint fulfilled. Stopping generation.")
        break

    # Update bitmask for the next step
    matcher.fill_next_token_bitmask(token_bitmask)


    generated_ids = torch.cat([generated_ids, next_token], dim=-1)

    # Stop if model finishes grammar
    if next_token.item() == tokenizer.eos_token_id:
        break

print(tokenizer.decode(generated_ids[0]))
# Out:
# Grammar constraint fulfilled. Stopping generation.
# Generate a profile for a developer named Alice who is 30 and knows Python.{ "name": "Alice", "age": 30, "skills": ["Python"] }
